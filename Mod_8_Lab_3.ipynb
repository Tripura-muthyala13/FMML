# %% [markdown]
# <a href="https://colab.research.google.com/github/Tripura-muthyala13/FMML/blob/main/Mod_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-06 17:06:41--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  74.0MB/s    in 0.9s
#
# 2024-04-06 17:06:42 (74.0 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7515   1801.09827v1  It is well-known that the robustness of artifi...  stat
# 13947  1610.01439v1  Neural networks are known to be effective func...    cs
# 27940  1705.00938v2  Training deep fully convolutional neural netwo...    cs
# 36364   1212.6216v2  Dribbling an opponent player in digital soccer...    cs
# 9058   1605.06778v1  We introduce openXBOW, an open-source toolkit ...    cs
# ...             ...                                                ...   ...
# 30807  1801.04654v1  Hyperspectral cameras preserve the fine spectr...    cs
# 10905  1612.03350v1  We propose an algorithm for the non-negative f...    cs
# 18248   0705.0197v1  Gaussian mixture models (GMM) and support vect...    cs
# 23055  1802.08598v2  Predictive models that generalize well under d...  stat
# 23906   1303.2437v1  Signal space models in both phase-encode, and ...    cs
#
#                                                    title  year  \
# 7515   Robustness of classification ability of spikin...  2018
# 13947  Nonlinear Systems Identification Using Deep Dy...  2016
# 27940  Error Corrective Boosting for Learning Fully C...  2017
# 36364  Generating Motion Patterns Using Evolutionary ...  2012
# 9058   openXBOW - Introducing the Passau Open-Source ...  2016
# ...                                                  ...   ...
# 30807  Hyperspectral recovery from RGB images using G...  2018
# 10905  Non-negative Factorization of the Occurrence T...  2016
# 18248  Fault Classification in Cylinders Using Multil...  2007
# 23055  Learning Weighted Representations for Generali...  2018
# 23906  Least-Squares FIR Models of Low-Resolution MR ...  2013
#
#                                                 keywords
# 7515   [robustness, artificial, important, applicatio...
# 13947  [effective, approximators, effective, recognit...
# 27940  [convolutional, segmentation, unlabeled, avail...
# 36364  [dribbling, environment, important, practical,...
# 9058   [introduce, generation, representations, multi...
# ...                                                  ...
# 30807  [hyperspectral, generally, traditional, quanti...
# 10905  [algorithm, factorization, occurrence, heterog...
# 18248  [introduced, population, cylindrical, procedur...
# 23055  [predictive, generalize, distributional, desir...
# 23906  [frequency, directions, presented, extrapolati...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7515     [robustness, artificial, important, applicatio...
# 13947    [effective, approximators, effective, recognit...
# 27940    [convolutional, segmentation, unlabeled, avail...
# 36364    [dribbling, environment, important, practical,...
# 9058     [introduce, generation, representations, multi...
#                                ...
# 12696    [processes, information, prediction, abilities...
# 14267    [dependent, textitactivity, transitions, emiss...
# 1374     [artificial, remarkable, different, empirical,...
# 22619    [computing, partition, important, statistical,...
# 23018    [deadliest, detection, widespread, challenge, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8916 words.
# Out of those 4603 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="74c9877b-8003-4632-9915-e9557ffb753e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74c9877b-8003-4632-9915-e9557ffb753e")) {                    Plotly.newPlot(                        "74c9877b-8003-4632-9915-e9557ffb753e",                        [{"x":["reduction","important","extensive","arbitrary","applications","benchmark","investigated","classification","perturbation","experiments","algorithm","significant","robustness","perturbations","classical","sinusoidal","artificial","perturbed","numerical","effectiveness","recognition","approximators","identification","evaluations","realworld","available","demonstrate","associated","investigate","nonlinear","underlying","investigates","effective","sequential","characteristics","dynamical","structures","estimators","initially","application","inclusion","introduce","comparison","auxiliary","emphasizes","unpooling","segmentation","upsampling","automatically","connections","parameter","performance","unlabeled","subsequent","boundaries","corrective","improvements","convolutional","architecture","annotations","challenges","imbalance","furthermore","addresses","outperforms","characteristic","trajectory","generating","environment","trajectories","triangulation","increment","computational","interpolation","transferring","approximate","evolutionary","procedure","computation","practical","generalized","information","complexities","multimodal","extensions","introducing","principle","descriptors","continuous","knowledge","representation","histograms","generation","sentiment","concatenates","exemplified","representations","quantisation","scenarios","capabilities","framework","surrogate","supervised","performed","observable","simulated","observations","leveraging","impossible","algorithmic","principles","intention","characterize","imitation","approaches","sophisticated","interfaces","realistic","parameters","aggregation","demonstrated","movements","algorithms","naturalistic","specifically","interface","distortion","approximation","transformation","deformation","handwritten","expecting","eliminate","cluttered","implement","emergence","advantages","interference","disadvantages","geometric","transformer","hierarchical","alignment","displacement","researchers","diagnostic","retrieved","extracted","experimental","retrieving","educational","improving","retrieval","transformed","efficiency","combining","characterization","represent","statistical","properties","corresponding","transition","combinatorial","connectivity","landscape","probabilities","exhaustively","attraction","representative","landscapes","instances","difficulty","evaluated","predictive","resulting","baselines","effectively","prediction","summarizing","theoretical","modifications","increased","functions","ambiguity","perspective","optimization","simultaneously","typically","efficient","significantly","interesting","multiclass","established","competitive","comparing","evaluation","different","asymmetric","asymmetry","similarity"],"y":[106,356,172,73,416,205,46,508,14,612,768,233,103,21,116,1,153,6,71,211,368,3,104,52,3,286,564,124,161,55,136,25,247,67,83,16,131,22,18,248,12,330,137,19,3,1,211,5,208,64,116,902,48,31,41,3,143,383,266,75,120,11,149,50,259,18,19,119,131,23,3,3,304,17,19,112,56,116,138,127,81,677,7,30,34,49,54,49,110,337,345,12,142,45,2,6,240,2,87,51,545,16,196,138,22,65,72,49,18,49,34,9,33,7,412,26,13,64,234,22,87,8,581,1,183,28,19,106,70,21,27,2,10,13,63,16,82,7,7,65,5,110,54,6,87,21,12,126,367,10,5,104,124,30,139,118,42,118,172,212,126,35,41,22,5,66,7,2,38,2,100,37,141,56,168,55,112,207,7,150,21,45,214,18,66,319,107,88,384,274,66,3,45,115,86,265,728,6,3,140],"type":"bar"},{"x":["reduction","important","extensive","a ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4603,), (4603, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Quality</span> <span style=''>Aware</span> <span style=''>Network</span> <span style=''>for</span> <span style=''>Set</span> <span style=''>to</span> <span style=''>Set</span> <span style='background-color:rgba(0, 255, 0, 0.6247240618101544);'>Recognition</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>targets</span> <span style=''>on</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>set</span> <span style=''>to</span> <span style=''>set</span> <span style='background-color:rgba(0, 255, 0, 0.6247240618101544);'>recognition</span> <span style=''>which</span> <span style=''>learns</span> <span style=''>the</span> <span style=''>metric</span> <span style=''>between</span> <span style=''>two</span> <span style=''>image</span> <span style=''>sets</span> <span style=''>Images</span> <span style=''>in</span> <span style=''>each</span> <span style=''>set</span> <span style=''>belong</span> <span style=''>to</span> <span style=''>the</span> <span style=''>same</span> <span style=''>identity</span> <span style=''>Since</span> <span style=''>images</span> <span style=''>in</span> <span style=''>a</span> <span style=''>set</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.42307692307692296);'>complementary</span> <span style=''>they</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>hopefully</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>higher</span> <span style=''>accuracy</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>However</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>each</span> <span style=''>sample</span> <span style=''>cannot</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.31343283582089554);'>guaranteed</span> <span style=''>and</span> <span style=''>samples</span> <span style=''>with</span> <span style=''>poor</span> <span style=''>quality</span> <span style=''>will</span> <span style=''>hurt</span> <span style=''>the</span> <span style=''>metric</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>aware</span> <span style=''>network</span> <span style=''>(QAN)</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>confront</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>each</span> <span style=''>sample</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.4295532646048109);'>automatically</span> <span style=''>learned</span> <span style=''>although</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explicitly</span> <span style=''>provided</span> <span style=''>in</span> <span style=''>the</span> <span style=''>training</span> <span style=''>stage</span> <span style=''>The</span> <span style=''>network</span> <span style=''>has</span> <span style=''>two</span> <span style=''>branches</span> <span style=''>where</span> <span style=''>the</span> <span style=''>first</span> <span style=''>branch</span> <span style=''>extracts</span> <span style='background-color:rgba(0, 255, 0, 0.942857142857143);'>appearance</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>for</span> <span style=''>each</span> <span style=''>sample</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimating</span> <span style=''>Subagging</span> <span style=''>by</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>derive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>concentration</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequalities</span> <span style=''>for</span> <span style=''>the</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style=''>estimate</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>for</span> <span style=''>subagged</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>both</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regressor</span> <span style=''>General</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>with</span> <span style=''>both</span> <span style=''>finite</span> <span style=''>and</span> <span style=''>infinite</span> <span style=''>VC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>We</span> <span style=''>slightly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalism</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>by</span> <span style=''>citeDUD03</span> <span style=''>to</span> <span style=''>cover</span> <span style=''>a</span> <span style=''>large</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedures</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>leave</span> <span style=''>one</span> <span style=''>out</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style=''>k</span> <span style=''>fold</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style=''>hold</span> <span style=''>out</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style=''>(or</span> <span style=''>split</span> <span style=''>sample)</span> <span style=''>and</span> <span style=''>the</span> <span style=''>leave</span> <span style=''>upsilon</span> <span style=''>out</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>validation</span> <span style=''>bigskip</span> <span style=''>noindent</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interesting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequence</span> <span style=''>is</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>is</span> <span style=''>bounded</span> <span style=''>by</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>of</span> <span style=''>a</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Modeling</span> <span style=''>Human</span> <span style=''>Decision</span> <span style=''>making</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalized</span> <span style=''>Gaussian</span> <span style=''>Multi</span> <span style=''>armed</span> <span style=''>Bandits</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>formal</span> <span style=''>model</span> <span style=''>of</span> <span style=''>human</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>in</span> <span style=''>explore</span> <span style=''>exploit</span> <span style=''>tasks</span> <span style=''>using</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>maker</span> <span style=''>must</span> <span style=''>choose</span> <span style=''>among</span> <span style=''>multiple</span> <span style=''>options</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.47826086956521735);'>uncertain</span> <span style=''>rewards</span> <span style=''>We</span> <span style=''>address</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>costs</span> <span style=''>and</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>on</span> <span style=''>graphs</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style=''>rewards</span> <span style=''>in</span> <span style=''>a</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>maker</span> <span style=''>uses</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>reward</span> <span style=''>values</span> <span style=''>We</span> <span style=''>model</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>makers</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3896907216494845);'>knowledge</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>prior</span> <span style=''>on</span> <span style=''>the</span> <span style=''>mean</span> <span style=''>reward</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>the</span> <span style=''>upper</span> <span style=''>credible</span> <span style=''>limit</span> <span style=''>(UCL)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>achieves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>logarit ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style=''>of</span> <span style=''>Cell</span> <span style=''>Images</span> <span style=''>Using</span> <span style=''>MPEG</span> <span style=''>7</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>influenced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Descriptors</span> <span style=''>and</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <span style=''>in</span> <span style=''>Cell</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Morphology</span> <br/><br/><span style=''>Counting</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifying</span> <span style=''>blood</span> <span style=''>cells</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diagnostic</span> <span style=''>tool</span> <span style=''>in</span> <span style=''>medicine</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style=''>popular</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style=''>could</span> <span style=''>replace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>systems</span> <span style=''>Here</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>blood</span> <span style=''>cells</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>using</span> <span style=''>SVM</span> <span style=''>A</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>on</span> <span style=''>images</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>in</span> <span style=''>C</span> <span style=''>The</span> <span style=''>MPEG</span> <span style=''>7</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>descriptors</span> <span style=''>Scalable</span> <span style=''>Color</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Descriptor</span> <span style=''>Color</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Descriptor</span> <span style=''>Color</span> <span style=''>Layout</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Descriptor</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Homogeneous</span> <span style=''>Texture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Descriptor</span> <span style=''>are</span> <span style=''>extended</span> <span style=''>in</span> <span style=''>size</span> <span style=''>and</span> <span style=''>combined</span> <span style=''>with</span> <span style=''>textural</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>textural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perceived</span> <span style=''>visually</span> <span style=''>by</span> <span style=''>humans</span> <span style=''>From</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>images</span> <span style=''>of</span> <span style=''>human</span> <span style=''>blood</span> <span style=''>cells</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.11941885187810064)
# 	experimental (0.130049610205528)
# 	processing (0.10524450744153083)
# 	evaluation (0.09390503189227498)
# 	segmentation (0.07476966690290573)
# 	architecture (0.09425939050318922)
# 	different (0.2579730687455705)
# 	detection (0.12402551381998582)
# 	recognition (0.13040396881644223)
# 	convolutional (0.13571934798015592)
#
# Some Statistics words are:
# 	variables (0.14459049544994945)
# 	statistical (0.15470171890798787)
# 	stochastic (0.13498483316481294)
# 	distribution (0.18048533872598585)
# 	theoretical (0.15874620829120323)
# 	estimation (0.18048533872598585)
# 	dimensional (0.179474216380182)
# 	inference (0.2012133468149646)
# 	algorithm (0.4019211324570273)
# 	regression (0.17593528816986856)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5f81f4b8-bc32-4b65-915d-6465f548732f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f81f4b8-bc32-4b65-915d-6465f548732f")) {                    Plotly.newPlot(                        "5f81f4b8-bc32-4b65-915d-6465f548732f",                        [{"x":["reduction","important","extensive","arbitrary","applications","benchmark","investigated","classification","perturbation","experiments","algorithm","significant","robustness","perturbations","classical","sinusoidal","artificial","perturbed","numerical","effectiveness","recognition","approximators","identification","evaluations","realworld","available","demonstrate","associated","investigate","nonlinear","underlying","investigates","effective","sequential","characteristics","dynamical","structures","estimators","initially","application","inclusion","introduce","comparison","auxiliary","emphasizes","unpooling","segmentation","upsampling","automatically","connections","parameter","performance","unlabeled","subsequent","boundaries","corrective","improvements","convolutional","architecture","annotations","challenges","imbalance","furthermore","addresses","outperforms","characteristic","trajectory","generating","environment","trajectories","triangulation","increment","computational","interpolation","transferring","approximate","evolutionary","procedure","computation","practical","generalized","information","complexities","multimodal","extensions","introducing","principle","descriptors","continuous","knowledge","representation","histograms","generation","sentiment","concatenates","exemplified","representations","quantisation","scenarios","capabilities","framework","surrogate","supervised","performed","observable","simulated","observations","leveraging","impossible","algorithmic","principles","intention","characterize","imitation","approaches","sophisticated","interfaces","realistic","parameters","aggregation","demonstrated","movements","algorithms","naturalistic","specifically","interface","distortion","approximation","transformation","deformation","handwritten","expecting","eliminate","cluttered","implement","emergence","advantages","interference","disadvantages","geometric","transformer","hierarchical","alignment","displacement","researchers","diagnostic","retrieved","extracted","experimental","retrieving","educational","improving","retrieval","transformed","efficiency","combining","characterization","represent","statistical","properties","corresponding","transition","combinatorial","connectivity","landscape","probabilities","exhaustively","attraction","representative","landscapes","instances","difficulty","evaluated","predictive","resulting","baselines","effectively","prediction","summarizing","theoretical","modifications","increased","functions","ambiguity","perspective","optimization","simultaneously","typically","efficient","significantly","interesting","multiclass","established","competitive","comparing","evaluation","different","asymmetric","asymmetry","similarity","guarantees","sensitive","empirical","designing","symmetric","causality","observational","statisticians","estimated","challenging","statistician","beginning","imputation","unfamiliar","estimation","incomplete","judiciously","estimating","structure","complexity","documents","introduced","alternative","representing","naturally","illustrate","operators","dictionaries","combinations","extension","techniques","accelerated","elementary","gracefully","traditional","computable","providing","precisely","composition","difficult","structured","regularized","regularization","reconstruction","dictionary","variables","probabilistic","hierarchies","prespecified","repeatedly","outperform","modelling","recurrent","practiti ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	statisticians
# 	statistician
# 	prespecified
# 	elucidate
# 	scleroderma
# 	autoimmune
# 	subpopulation
# 	censoring
# 	nonlinearly
# 	readmission
# 	advantageously
# 	nonconjugate
# 	deteriorates
# 	homogenous
# 	anchoring
# 	representer
# 	maximising
# 	unscented
# 	psychiatric
# 	parametrically
# Some words which never appear in Statistics papers:
# 	realworld
# 	upsampling
# 	corrective
# 	triangulation
# 	increment
# 	concatenates
# 	exemplified
# 	quantisation
# 	transformer
# 	articulated
# 	acquisitions
# 	interconnected
# 	concatenation
# 	exhausted
# 	extrinsic
# 	backgrounds
# 	imitating
# 	compliance
# 	ecological
# 	capacities

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0466441215001674e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7508333333333334
